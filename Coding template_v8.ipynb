# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import itertools
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
from sklearn.model_selection import KFold

# %%
# Define the number of rows for the synthetic dataset
num_rows = 2421

# Generate synthetic data for each column
order_date = [datetime(2009, 1, 1) + timedelta(days=np.random.randint(730)) for _ in range(num_rows)]
requested_delivery_date = [date + timedelta(days=np.random.randint(30)) for date in order_date]
country_codes = np.random.choice(['US', 'UK', 'DE', 'FR', 'IT'], size=num_rows)
product_codes = np.random.choice(['P001', 'P002', 'P003'], size=num_rows)
descriptions = [f'Description_{i}' for i in range(1, num_rows + 1)]
order_types = np.random.choice(['VO', 'Non-VO'], size=num_rows)
customer_order_codes = np.random.randint(1000, 2000, size=num_rows)
values = np.random.uniform(50, 500, size=num_rows)
currencies = np.random.choice(['USD', 'EUR', 'GBP'], size=num_rows)

items = np.random.randint(1, 800, size=num_rows)

routes = np.random.choice(['Route_A', 'Route_B', 'Route_C'], size=num_rows)

requested_delivery_date = []
for i in range(num_rows):
    if order_types[i] == 'VO':
        requested_delivery_date.append(order_date[i] + timedelta(days=np.random.randint(27, 34)))
    else:
        requested_delivery_date.append(order_date[i] + timedelta(days=np.random.randint(30)))

# %%
# Create a DataFrame with the generated data
data = pd.DataFrame({
    'Order Date': order_date,
    'Requested Delivery Date': requested_delivery_date,
    'Customer Country Code': country_codes,
    'Product Code': product_codes,
    'Description': descriptions,
    'Order type': order_types,
    'Customer Order Code': customer_order_codes,
    'Value': values,
    'Currency': currencies,
    'Items': items,
    'Route': routes
})

# %%
data
# Out:
#      Order Date Requested Delivery Date Customer Country Code Product Code
# 0    2010-03-28              2010-04-16                    FR         P002  \
# 1    2010-12-22              2011-01-12                    DE         P003
# 2    2009-02-10              2009-03-09                    UK         P003
# 3    2010-12-15              2010-12-22                    US         P002
# 4    2010-03-22              2010-03-31                    FR         P002
# ...         ...                     ...                   ...          ...
# 2416 2009-11-30              2009-12-15                    FR         P002
# 2417 2009-06-12              2009-06-27                    FR         P001
# 2418 2010-05-23              2010-06-22                    DE         P002
# 2419 2009-04-05              2009-05-04                    IT         P002
# 2420 2010-10-04              2010-11-04                    UK         P003
#
#            Description Order type  Customer Order Code       Value Currency
# 0        Description_1     Non-VO                 1854  382.706394      EUR  \
# 1        Description_2     Non-VO                 1634  223.874999      USD
# 2        Description_3         VO                 1350  305.198381      GBP
# 3        Description_4     Non-VO                 1748   59.290286      EUR
# 4        Description_5     Non-VO                 1341  288.235547      GBP
# ...                ...        ...                  ...         ...      ...
# 2416  Description_2417     Non-VO                 1476  184.410110      EUR
# 2417  Description_2418     Non-VO                 1320   86.185526      GBP
# 2418  Description_2419         VO                 1734  127.730830      USD
# 2419  Description_2420         VO                 1398  188.441904      GBP
# 2420  Description_2421         VO                 1403  122.336466      GBP
#
#       Items    Route
# 0       492  Route_C
# 1       510  Route_B
# 2       764  Route_A
# 3       486  Route_C
# 4       316  Route_B
# ...     ...      ...
# 2416    622  Route_A
# 2417    341  Route_B
# 2418    321  Route_B
# 2419    732  Route_B
# 2420    198  Route_C
#
# [2421 rows x 11 columns]

# %%
data['MOY_Requested Delivery Date'] = data['Requested Delivery Date'].dt.month

# %%
data
# Out:
#      Order Date Requested Delivery Date Customer Country Code Product Code
# 0    2010-03-28              2010-04-16                    FR         P002  \
# 1    2010-12-22              2011-01-12                    DE         P003
# 2    2009-02-10              2009-03-09                    UK         P003
# 3    2010-12-15              2010-12-22                    US         P002
# 4    2010-03-22              2010-03-31                    FR         P002
# ...         ...                     ...                   ...          ...
# 2416 2009-11-30              2009-12-15                    FR         P002
# 2417 2009-06-12              2009-06-27                    FR         P001
# 2418 2010-05-23              2010-06-22                    DE         P002
# 2419 2009-04-05              2009-05-04                    IT         P002
# 2420 2010-10-04              2010-11-04                    UK         P003
#
#            Description Order type  Customer Order Code       Value Currency
# 0        Description_1     Non-VO                 1854  382.706394      EUR  \
# 1        Description_2     Non-VO                 1634  223.874999      USD
# 2        Description_3         VO                 1350  305.198381      GBP
# 3        Description_4     Non-VO                 1748   59.290286      EUR
# 4        Description_5     Non-VO                 1341  288.235547      GBP
# ...                ...        ...                  ...         ...      ...
# 2416  Description_2417     Non-VO                 1476  184.410110      EUR
# 2417  Description_2418     Non-VO                 1320   86.185526      GBP
# 2418  Description_2419         VO                 1734  127.730830      USD
# 2419  Description_2420         VO                 1398  188.441904      GBP
# 2420  Description_2421         VO                 1403  122.336466      GBP
#
#       Items    Route  MOY_Requested Delivery Date
# 0       492  Route_C                            4
# 1       510  Route_B                            1
# 2       764  Route_A                            3
# 3       486  Route_C                           12
# 4       316  Route_B                            3
# ...     ...      ...                          ...
# 2416    622  Route_A                           12
# 2417    341  Route_B                            6
# 2418    321  Route_B                            6
# 2419    732  Route_B                            5
# 2420    198  Route_C                           11
#
# [2421 rows x 12 columns]

# %%
exchange_rates = {'USD': 1.26, 'EUR': 1.48}

# %%
data['Value_CAD'] = data.apply(lambda row: row['Value'] * exchange_rates.get(row['Currency'], 1), axis=1)

# %%
data['Total_Price'] = data['Value_CAD'] * data['Items']

# %%
agg_data = data.groupby(['Product Code', 'MOY_Requested Delivery Date']).agg({'Total_Price': 'sum', 'Items': 'sum'}).reset_index()

# %%
agg_data['Average_Price'] = agg_data['Total_Price'] / agg_data['Items']

# %%
label_encoder = LabelEncoder()
agg_data['Product Code'] = label_encoder.fit_transform(agg_data['Product Code']) + 1

# %%
df_choice=agg_data.drop(['Total_Price'], axis=1)

# %%
X = df_choice.drop(['Product Code'], axis=1)
Y = df_choice['Product Code']

# %%
X
# Out:
#     MOY_Requested Delivery Date  Items  Average_Price
# 0                             1  29798     345.787470
# 1                             2  23080     356.820775
# 2                             3  26428     303.017557
# 3                             4  23712     358.449826
# 4                             5  34719     365.152850
# 5                             6  27533     392.939217
# 6                             7  28774     336.888834
# 7                             8  28657     313.052387
# 8                             9  27499     352.316930
# 9                            10  30394     317.158946
# 10                           11  19647     302.945577
# 11                           12  28629     349.036793
# 12                            1  29187     329.705733
# 13                            2  21979     352.708207
# 14                            3  28061     355.760347
# 15                            4  33099     327.588813
# 16                            5  27826     317.440634
# 17                            6  20060     377.243758
# 18                            7  24212     332.984805
# 19                            8  24083     339.495190
# 20                            9  25255     297.057938
# 21                           10  24250     344.166979
# 22                           11  27239     356.666522
# 23                           12  23863     310.472388
# 24                            1  23646     338.366646
# 25                            2  28996     336.927107
# 26                            3  25666     358.583927
# 27                            4  29871     346.402851
# 28                            5  32445     328.771959
# 29                            6  24629     370.390075
# 30                            7  25550     356.034787
# 31                            8  24049     359.189148
# 32                            9  19283     329.392293
# 33                           10  34626     361.215554
# 34                           11  27849     355.458543
# 35                           12  24137     346.279784

# %%
X = sm.add_constant(X)

# %%
X
# Out:
#     const  MOY_Requested Delivery Date  Items  Average_Price
# 0     1.0                            1  29798     345.787470
# 1     1.0                            2  23080     356.820775
# 2     1.0                            3  26428     303.017557
# 3     1.0                            4  23712     358.449826
# 4     1.0                            5  34719     365.152850
# 5     1.0                            6  27533     392.939217
# 6     1.0                            7  28774     336.888834
# 7     1.0                            8  28657     313.052387
# 8     1.0                            9  27499     352.316930
# 9     1.0                           10  30394     317.158946
# 10    1.0                           11  19647     302.945577
# 11    1.0                           12  28629     349.036793
# 12    1.0                            1  29187     329.705733
# 13    1.0                            2  21979     352.708207
# 14    1.0                            3  28061     355.760347
# 15    1.0                            4  33099     327.588813
# 16    1.0                            5  27826     317.440634
# 17    1.0                            6  20060     377.243758
# 18    1.0                            7  24212     332.984805
# 19    1.0                            8  24083     339.495190
# 20    1.0                            9  25255     297.057938
# 21    1.0                           10  24250     344.166979
# 22    1.0                           11  27239     356.666522
# 23    1.0                           12  23863     310.472388
# 24    1.0                            1  23646     338.366646
# 25    1.0                            2  28996     336.927107
# 26    1.0                            3  25666     358.583927
# 27    1.0                            4  29871     346.402851
# 28    1.0                            5  32445     328.771959
# 29    1.0                            6  24629     370.390075
# 30    1.0                            7  25550     356.034787
# 31    1.0                            8  24049     359.189148
# 32    1.0                            9  19283     329.392293
# 33    1.0                           10  34626     361.215554
# 34    1.0                           11  27849     355.458543
# 35    1.0                           12  24137     346.279784

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
model = sm.MNLogit(Y_train, X_train)
result = model.fit(ref_cat=1)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.041933
#          Iterations 5
# c:\Users\tn_ad\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\base\optimizer.py:18: FutureWarning: Keyword arguments have been passed to the optimizer that have no effect. The list of allowed keyword arguments for method newton is: tol, ridge_factor. The list of unsupported keyword arguments passed include: ref_cat. After release 0.14, this will raise.
#   warnings.warn(

# %%
print(result.summary())
# Out:
#                           MNLogit Regression Results
# ==============================================================================
# Dep. Variable:           Product Code   No. Observations:                   28
# Model:                        MNLogit   Df Residuals:                       20
# Method:                           MLE   Df Model:                            6
# Date:                Sat, 09 Dec 2023   Pseudo R-squ.:                 0.03435
# Time:                        22:50:23   Log-Likelihood:                -29.174
# converged:                       True   LL-Null:                       -30.212
# Covariance Type:            nonrobust   LLR p-value:                    0.9126
# ===============================================================================================
#              Product Code=2       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                           2.5957      7.627      0.340      0.734     -12.353      17.544
# MOY_Requested Delivery Date     0.0715      0.144      0.498      0.618      -0.210       0.353
# Items                       -9.598e-05      0.000     -0.802      0.423      -0.000       0.000
# Average_Price                  -0.0028      0.020     -0.137      0.891      -0.043       0.037
# -----------------------------------------------------------------------------------------------
#              Product Code=3       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------
# const                          -3.5198      7.887     -0.446      0.655     -18.978      11.938
# MOY_Requested Delivery Date    -0.0379      0.139     -0.272      0.785      -0.311       0.235
# Items                        1.242e-05      0.000      0.107      0.915      -0.000       0.000
# Average_Price                   0.0088      0.021      0.420      0.674      -0.032       0.050
# ===============================================================================================

# %%
Y_prob = result.predict(X_test_scaled)

# %%
print(Y_prob)
# Out:
# [[0.3264749  0.36555242 0.30797269]
#  [0.33747406 0.30545208 0.35707386]
#  [0.33643235 0.31078646 0.35278119]
#  [0.33251462 0.33445897 0.33302641]
#  [0.33579488 0.32523237 0.33897275]
#  [0.33128249 0.34024243 0.32847509]
#  [0.32922072 0.35341137 0.31736791]
#  [0.33907169 0.30124533 0.35968298]]

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (2.0.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (1.2.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (3.0.6)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (1.24.3)
# Requirement already satisfied: pandas>=0.19 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (2.0.1)
# Requirement already satisfied: scikit-learn>=0.22 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (1.2.2)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (1.10.1)
# Requirement already satisfied: statsmodels>=0.13.2 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (0.14.0)
# Requirement already satisfied: urllib3 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (2.0.4)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from pmdarima) (68.0.0)
# Requirement already satisfied: packaging>=17.1 in c:\users\tn_ad\appdata\roaming\python\python311\site-packages (from pmdarima) (23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\tn_ad\appdata\roaming\python\python311\site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.19->pmdarima) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn>=0.22->pmdarima) (3.1.0)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\tn_ad\appdata\local\programs\python\python311\lib\site-packages (from statsmodels>=0.13.2->pmdarima) (0.5.3)
# Requirement already satisfied: six in c:\users\tn_ad\appdata\roaming\python\python311\site-packages (from patsy>=0.5.2->statsmodels>=0.13.2->pmdarima) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from pmdarima import auto_arima
from sklearn.model_selection import TimeSeriesSplit

# %%
data
# Out:
#      Order Date Requested Delivery Date Customer Country Code Product Code
# 0    2010-03-28              2010-04-16                    FR         P002  \
# 1    2010-12-22              2011-01-12                    DE         P003
# 2    2009-02-10              2009-03-09                    UK         P003
# 3    2010-12-15              2010-12-22                    US         P002
# 4    2010-03-22              2010-03-31                    FR         P002
# ...         ...                     ...                   ...          ...
# 2416 2009-11-30              2009-12-15                    FR         P002
# 2417 2009-06-12              2009-06-27                    FR         P001
# 2418 2010-05-23              2010-06-22                    DE         P002
# 2419 2009-04-05              2009-05-04                    IT         P002
# 2420 2010-10-04              2010-11-04                    UK         P003
#
#            Description Order type  Customer Order Code       Value Currency
# 0        Description_1     Non-VO                 1854  382.706394      EUR  \
# 1        Description_2     Non-VO                 1634  223.874999      USD
# 2        Description_3         VO                 1350  305.198381      GBP
# 3        Description_4     Non-VO                 1748   59.290286      EUR
# 4        Description_5     Non-VO                 1341  288.235547      GBP
# ...                ...        ...                  ...         ...      ...
# 2416  Description_2417     Non-VO                 1476  184.410110      EUR
# 2417  Description_2418     Non-VO                 1320   86.185526      GBP
# 2418  Description_2419         VO                 1734  127.730830      USD
# 2419  Description_2420         VO                 1398  188.441904      GBP
# 2420  Description_2421         VO                 1403  122.336466      GBP
#
#       Items    Route  MOY_Requested Delivery Date   Value_CAD    Total_Price
# 0       492  Route_C                            4  566.405464  278671.488205
# 1       510  Route_B                            1  282.082499  143862.074344
# 2       764  Route_A                            3  305.198381  233171.563227
# 3       486  Route_C                           12   87.749623   42646.316813
# 4       316  Route_B                            3  288.235547   91082.432974
# ...     ...      ...                          ...         ...            ...
# 2416    622  Route_A                           12  272.926963  169760.571245
# 2417    341  Route_B                            6   86.185526   29389.264286
# 2418    321  Route_B                            6  160.940846   51662.011464
# 2419    732  Route_B                            5  188.441904  137939.473919
# 2420    198  Route_C                           11  122.336466   24222.620192
#
# [2421 rows x 14 columns]

# %%
data['Requested Delivery Date'] = pd.to_datetime(data['Requested Delivery Date'])
data['Delivery Month'] = (
    (data['Requested Delivery Date'].dt.year - data['Requested Delivery Date'].dt.year.min()) * 12 +
    data['Requested Delivery Date'].dt.month
)

# %%
data
# Out:
#      Order Date Requested Delivery Date Customer Country Code Product Code
# 0    2010-03-28              2010-04-16                    FR         P002  \
# 1    2010-12-22              2011-01-12                    DE         P003
# 2    2009-02-10              2009-03-09                    UK         P003
# 3    2010-12-15              2010-12-22                    US         P002
# 4    2010-03-22              2010-03-31                    FR         P002
# ...         ...                     ...                   ...          ...
# 2416 2009-11-30              2009-12-15                    FR         P002
# 2417 2009-06-12              2009-06-27                    FR         P001
# 2418 2010-05-23              2010-06-22                    DE         P002
# 2419 2009-04-05              2009-05-04                    IT         P002
# 2420 2010-10-04              2010-11-04                    UK         P003
#
#            Description Order type  Customer Order Code       Value Currency
# 0        Description_1     Non-VO                 1854  382.706394      EUR  \
# 1        Description_2     Non-VO                 1634  223.874999      USD
# 2        Description_3         VO                 1350  305.198381      GBP
# 3        Description_4     Non-VO                 1748   59.290286      EUR
# 4        Description_5     Non-VO                 1341  288.235547      GBP
# ...                ...        ...                  ...         ...      ...
# 2416  Description_2417     Non-VO                 1476  184.410110      EUR
# 2417  Description_2418     Non-VO                 1320   86.185526      GBP
# 2418  Description_2419         VO                 1734  127.730830      USD
# 2419  Description_2420         VO                 1398  188.441904      GBP
# 2420  Description_2421         VO                 1403  122.336466      GBP
#
#       Items    Route  MOY_Requested Delivery Date   Value_CAD    Total_Price
# 0       492  Route_C                            4  566.405464  278671.488205  \
# 1       510  Route_B                            1  282.082499  143862.074344
# 2       764  Route_A                            3  305.198381  233171.563227
# 3       486  Route_C                           12   87.749623   42646.316813
# 4       316  Route_B                            3  288.235547   91082.432974
# ...     ...      ...                          ...         ...            ...
# 2416    622  Route_A                           12  272.926963  169760.571245
# 2417    341  Route_B                            6   86.185526   29389.264286
# 2418    321  Route_B                            6  160.940846   51662.011464
# 2419    732  Route_B                            5  188.441904  137939.473919
# 2420    198  Route_C                           11  122.336466   24222.620192
#
#       Delivery Month
# 0                 16
# 1                 25
# 2                  3
# 3                 24
# 4                 15
# ...              ...
# 2416              12
# 2417               6
# 2418              18
# 2419               5
# 2420              23
#
# [2421 rows x 15 columns]

# %%
demand = data.groupby(['Order type', 'Delivery Month']).agg({'Total_Price': 'sum', 'Items': 'sum'}).reset_index()

# %%
demand
# Out:
#    Order type  Delivery Month   Total_Price  Items
# 0      Non-VO               1  4.589957e+06  12266
# 1      Non-VO               2  5.256095e+06  15144
# 2      Non-VO               3  5.825314e+06  16621
# 3      Non-VO               4  6.631700e+06  22263
# 4      Non-VO               5  9.619035e+06  27069
# 5      Non-VO               6  5.130315e+06  12274
# 6      Non-VO               7  6.560863e+06  19534
# 7      Non-VO               8  4.053775e+06  14961
# 8      Non-VO               9  5.903531e+06  17394
# 9      Non-VO              10  8.228974e+06  21112
# 10     Non-VO              11  6.033372e+06  18071
# 11     Non-VO              12  6.993502e+06  20080
# 12     Non-VO              13  5.500618e+06  17753
# 13     Non-VO              14  4.881016e+06  15232
# 14     Non-VO              15  5.972640e+06  18825
# 15     Non-VO              16  8.676663e+06  22299
# 16     Non-VO              17  6.279346e+06  17935
# 17     Non-VO              18  7.752817e+06  18774
# 18     Non-VO              19  7.194538e+06  18758
# 19     Non-VO              20  7.483310e+06  19557
# 20     Non-VO              21  5.512245e+06  15775
# 21     Non-VO              22  6.177791e+06  20878
# 22     Non-VO              23  6.590063e+06  19661
# 23     Non-VO              24  5.692714e+06  14818
# 24     Non-VO              25  5.492709e+06  16475
# 25         VO               1  1.342595e+04     34
# 26         VO               2  6.998480e+06  20650
# 27         VO               3  6.665641e+06  19569
# 28         VO               4  7.996629e+06  23663
# 29         VO               5  8.812799e+06  26665
# 30         VO               6  8.877788e+06  23602
# 31         VO               7  4.781203e+06  15043
# 32         VO               8  5.587131e+06  18608
# 33         VO               9  5.530023e+06  18855
# 34         VO              10  8.980661e+06  26013
# 35         VO              11  4.858209e+06  13768
# 36         VO              12  6.615427e+06  20963
# 37         VO              13  6.581532e+06  19673
# 38         VO              14  8.562253e+06  22756
# 39         VO              15  8.730959e+06  25140
# 40         VO              16  6.384831e+06  18457
# 41         VO              17  7.466671e+06  23321
# 42         VO              18  5.747723e+06  17572
# 43         VO              19  8.315952e+06  25201
# 44         VO              20  8.661129e+06  23663
# 45         VO              21  6.596435e+06  20013
# 46         VO              22  7.105802e+06  21267
# 47         VO              23  8.084732e+06  23235
# 48         VO              24  6.457889e+06  20768
# 49         VO              25  5.749671e+06  16430
# 50         VO              26  5.929131e+04    273

# %%
demand['Advance_Order'] = (demand['Order type'] == 'VO') * demand['Items']
demand['Urgent_Order'] = (demand['Order type'] == 'Non-VO') * demand['Items']

# %%
demand
# Out:
#    Order type  Delivery Month   Total_Price  Items  Advance_Order
# 0      Non-VO               1  4.589957e+06  12266              0  \
# 1      Non-VO               2  5.256095e+06  15144              0
# 2      Non-VO               3  5.825314e+06  16621              0
# 3      Non-VO               4  6.631700e+06  22263              0
# 4      Non-VO               5  9.619035e+06  27069              0
# 5      Non-VO               6  5.130315e+06  12274              0
# 6      Non-VO               7  6.560863e+06  19534              0
# 7      Non-VO               8  4.053775e+06  14961              0
# 8      Non-VO               9  5.903531e+06  17394              0
# 9      Non-VO              10  8.228974e+06  21112              0
# 10     Non-VO              11  6.033372e+06  18071              0
# 11     Non-VO              12  6.993502e+06  20080              0
# 12     Non-VO              13  5.500618e+06  17753              0
# 13     Non-VO              14  4.881016e+06  15232              0
# 14     Non-VO              15  5.972640e+06  18825              0
# 15     Non-VO              16  8.676663e+06  22299              0
# 16     Non-VO              17  6.279346e+06  17935              0
# 17     Non-VO              18  7.752817e+06  18774              0
# 18     Non-VO              19  7.194538e+06  18758              0
# 19     Non-VO              20  7.483310e+06  19557              0
# 20     Non-VO              21  5.512245e+06  15775              0
# 21     Non-VO              22  6.177791e+06  20878              0
# 22     Non-VO              23  6.590063e+06  19661              0
# 23     Non-VO              24  5.692714e+06  14818              0
# 24     Non-VO              25  5.492709e+06  16475              0
# 25         VO               1  1.342595e+04     34             34
# 26         VO               2  6.998480e+06  20650          20650
# 27         VO               3  6.665641e+06  19569          19569
# 28         VO               4  7.996629e+06  23663          23663
# 29         VO               5  8.812799e+06  26665          26665
# 30         VO               6  8.877788e+06  23602          23602
# 31         VO               7  4.781203e+06  15043          15043
# 32         VO               8  5.587131e+06  18608          18608
# 33         VO               9  5.530023e+06  18855          18855
# 34         VO              10  8.980661e+06  26013          26013
# 35         VO              11  4.858209e+06  13768          13768
# 36         VO              12  6.615427e+06  20963          20963
# 37         VO              13  6.581532e+06  19673          19673
# 38         VO              14  8.562253e+06  22756          22756
# 39         VO              15  8.730959e+06  25140          25140
# 40         VO              16  6.384831e+06  18457          18457
# 41         VO              17  7.466671e+06  23321          23321
# 42         VO              18  5.747723e+06  17572          17572
# 43         VO              19  8.315952e+06  25201          25201
# 44         VO              20  8.661129e+06  23663          23663
# 45         VO              21  6.596435e+06  20013          20013
# 46         VO              22  7.105802e+06  21267          21267
# 47         VO              23  8.084732e+06  23235          23235
# 48         VO              24  6.457889e+06  20768          20768
# 49         VO              25  5.749671e+06  16430          16430
# 50         VO              26  5.929131e+04    273            273
#
#     Urgent_Order
# 0          12266
# 1          15144
# 2          16621
# 3          22263
# 4          27069
# 5          12274
# 6          19534
# 7          14961
# 8          17394
# 9          21112
# 10         18071
# 11         20080
# 12         17753
# 13         15232
# 14         18825
# 15         22299
# 16         17935
# 17         18774
# 18         18758
# 19         19557
# 20         15775
# 21         20878
# 22         19661
# 23         14818
# 24         16475
# 25             0
# 26             0
# 27             0
# 28             0
# 29             0
# 30             0
# 31             0
# 32             0
# 33             0
# 34             0
# 35             0
# 36             0
# 37             0
# 38             0
# 39             0
# 40             0
# 41             0
# 42             0
# 43             0
# 44             0
# 45             0
# 46             0
# 47             0
# 48             0
# 49             0
# 50             0

# %%
demand = demand.groupby(['Delivery Month']).agg({'Total_Price': 'sum', 'Advance_Order': 'sum', 'Urgent_Order': 'sum'}).reset_index()
demand['Average_Price'] = demand['Total_Price'] /(demand['Advance_Order']+demand['Urgent_Order'])

# %%
demand
# Out:
#     Delivery Month   Total_Price  Advance_Order  Urgent_Order  Average_Price
# 0                1  4.603383e+06             34         12266     374.258776
# 1                2  1.225458e+07          20650         15144     342.363948
# 2                3  1.249095e+07          19569         16621     345.149344
# 3                4  1.462833e+07          23663         22263     318.519566
# 4                5  1.843183e+07          26665         27069     343.019950
# 5                6  1.400810e+07          23602         12274     390.458889
# 6                7  1.134207e+07          15043         19534     328.023420
# 7                8  9.640907e+06          18608         14961     287.196716
# 8                9  1.143355e+07          18855         17394     315.417076
# 9               10  1.720963e+07          26013         21112     365.191192
# 10              11  1.089158e+07          13768         18071     342.083021
# 11              12  1.360893e+07          20963         20080     331.577349
# 12              13  1.208215e+07          19673         17753     322.827722
# 13              14  1.344327e+07          22756         15232     353.881991
# 14              15  1.470360e+07          25140         18825     334.438744
# 15              16  1.506149e+07          18457         22299     369.552811
# 16              17  1.374602e+07          23321         17935     333.188314
# 17              18  1.350054e+07          17572         18774     371.444981
# 18              19  1.551049e+07          25201         18758     352.839929
# 19              20  1.614444e+07          23663         19557     373.540911
# 20              21  1.210868e+07          20013         15775     338.344682
# 21              22  1.328359e+07          21267         20878     315.187877
# 22              23  1.467479e+07          23235         19661     342.101706
# 23              24  1.215060e+07          20768         14818     341.443347
# 24              25  1.124238e+07          16430         16475     341.661775
# 25              26  5.929131e+04            273             0     217.184268

# %%
df = demand.drop(['Total_Price'], axis=1)

# %%
df
# Out:
#     Delivery Month  Advance_Order  Urgent_Order  Average_Price
# 0                1             34         12266     374.258776
# 1                2          20650         15144     342.363948
# 2                3          19569         16621     345.149344
# 3                4          23663         22263     318.519566
# 4                5          26665         27069     343.019950
# 5                6          23602         12274     390.458889
# 6                7          15043         19534     328.023420
# 7                8          18608         14961     287.196716
# 8                9          18855         17394     315.417076
# 9               10          26013         21112     365.191192
# 10              11          13768         18071     342.083021
# 11              12          20963         20080     331.577349
# 12              13          19673         17753     322.827722
# 13              14          22756         15232     353.881991
# 14              15          25140         18825     334.438744
# 15              16          18457         22299     369.552811
# 16              17          23321         17935     333.188314
# 17              18          17572         18774     371.444981
# 18              19          25201         18758     352.839929
# 19              20          23663         19557     373.540911
# 20              21          20013         15775     338.344682
# 21              22          21267         20878     315.187877
# 22              23          23235         19661     342.101706
# 23              24          20768         14818     341.443347
# 24              25          16430         16475     341.661775
# 25              26            273             0     217.184268

# %%
df.set_index('Delivery Month', inplace=True)

# %%
df
# Out:
#                 Advance_Order  Urgent_Order  Average_Price
# Delivery Month
# 1                          34         12266     374.258776
# 2                       20650         15144     342.363948
# 3                       19569         16621     345.149344
# 4                       23663         22263     318.519566
# 5                       26665         27069     343.019950
# 6                       23602         12274     390.458889
# 7                       15043         19534     328.023420
# 8                       18608         14961     287.196716
# 9                       18855         17394     315.417076
# 10                      26013         21112     365.191192
# 11                      13768         18071     342.083021
# 12                      20963         20080     331.577349
# 13                      19673         17753     322.827722
# 14                      22756         15232     353.881991
# 15                      25140         18825     334.438744
# 16                      18457         22299     369.552811
# 17                      23321         17935     333.188314
# 18                      17572         18774     371.444981
# 19                      25201         18758     352.839929
# 20                      23663         19557     373.540911
# 21                      20013         15775     338.344682
# 22                      21267         20878     315.187877
# 23                      23235         19661     342.101706
# 24                      20768         14818     341.443347
# 25                      16430         16475     341.661775
# 26                        273             0     217.184268

# %%
df['Predict_Demand'] = df['Advance_Order'] + df['Urgent_Order']

# %%
df
# Out:
#                 Advance_Order  Urgent_Order  Average_Price  Predict_Demand
# Delivery Month
# 1                          34         12266     374.258776           12300
# 2                       20650         15144     342.363948           35794
# 3                       19569         16621     345.149344           36190
# 4                       23663         22263     318.519566           45926
# 5                       26665         27069     343.019950           53734
# 6                       23602         12274     390.458889           35876
# 7                       15043         19534     328.023420           34577
# 8                       18608         14961     287.196716           33569
# 9                       18855         17394     315.417076           36249
# 10                      26013         21112     365.191192           47125
# 11                      13768         18071     342.083021           31839
# 12                      20963         20080     331.577349           41043
# 13                      19673         17753     322.827722           37426
# 14                      22756         15232     353.881991           37988
# 15                      25140         18825     334.438744           43965
# 16                      18457         22299     369.552811           40756
# 17                      23321         17935     333.188314           41256
# 18                      17572         18774     371.444981           36346
# 19                      25201         18758     352.839929           43959
# 20                      23663         19557     373.540911           43220
# 21                      20013         15775     338.344682           35788
# 22                      21267         20878     315.187877           42145
# 23                      23235         19661     342.101706           42896
# 24                      20768         14818     341.443347           35586
# 25                      16430         16475     341.661775           32905
# 26                        273             0     217.184268             273

# %%
df_demand = df.drop(['Urgent_Order'], axis=1)

# %%
df_demand
# Out:
#                 Advance_Order  Average_Price  Predict_Demand
# Delivery Month
# 1                          34     374.258776           12300
# 2                       20650     342.363948           35794
# 3                       19569     345.149344           36190
# 4                       23663     318.519566           45926
# 5                       26665     343.019950           53734
# 6                       23602     390.458889           35876
# 7                       15043     328.023420           34577
# 8                       18608     287.196716           33569
# 9                       18855     315.417076           36249
# 10                      26013     365.191192           47125
# 11                      13768     342.083021           31839
# 12                      20963     331.577349           41043
# 13                      19673     322.827722           37426
# 14                      22756     353.881991           37988
# 15                      25140     334.438744           43965
# 16                      18457     369.552811           40756
# 17                      23321     333.188314           41256
# 18                      17572     371.444981           36346
# 19                      25201     352.839929           43959
# 20                      23663     373.540911           43220
# 21                      20013     338.344682           35788
# 22                      21267     315.187877           42145
# 23                      23235     342.101706           42896
# 24                      20768     341.443347           35586
# 25                      16430     341.661775           32905
# 26                        273     217.184268             273

# %%
train_size = int(len(df_demand) * 0.8)  # 80-20 split
train, test = df_demand[:train_size], df_demand[train_size:]

# %%
test
# Out:
#                 Advance_Order  Average_Price  Predict_Demand
# Delivery Month
# 21                      20013     338.344682           35788
# 22                      21267     315.187877           42145
# 23                      23235     342.101706           42896
# 24                      20768     341.443347           35586
# 25                      16430     341.661775           32905
# 26                        273     217.184268             273

# %%
order = (1, 1, 1)
seasonal_order = (1, 1, 1, 12)
exog_vars = ['Advance_Order', 'Average_Price']

# %%
stepwise_fit = auto_arima(train['Predict_Demand'], exogenous=train[exog_vars], start_p=1, start_q=1,
                          max_p=3, max_q=3, m=12, seasonal=True, stepwise=True, suppress_warnings=True,
                          error_action='ignore', scoring='mse')
# Out:
# c:\Users\tn_ad\AppData\Local\Programs\Python\Python311\Lib\site-packages\pmdarima\arima\utils.py:117: UserWarning: Appropriate D value may not have been reached; length of seasonally-differenced array (8) is shorter than m (12). Using D=1
#   warnings.warn("Appropriate D value may not have been reached; "

# %%
best_params = stepwise_fit.get_params()
best_params
# Out:
# {'maxiter': 50,
#  'method': 'lbfgs',
#  'order': (0, 0, 1),
#  'out_of_sample_size': 0,
#  'scoring': 'mse',
#  'scoring_args': {},
#  'seasonal_order': (0, 1, 1, 12),
#  'start_params': None,
#  'suppress_warnings': True,
#  'trend': None,
#  'with_intercept': True}

# %%
sarimax_model = sm.tsa.statespace.SARIMAX(train['Predict_Demand'], exog=train[exog_vars],
                                         order=(best_params['order']), seasonal_order=(best_params['seasonal_order']))
sarimax_result = sarimax_model.fit(disp=False)
# Out:
# c:\Users\tn_ad\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\tn_ad\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# c:\Users\tn_ad\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\tn_ad\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'

# %%
test
# Out:
#                 Advance_Order  Average_Price  Predict_Demand
# Delivery Month
# 21                      20013     338.344682           35788
# 22                      21267     315.187877           42145
# 23                      23235     342.101706           42896
# 24                      20768     341.443347           35586
# 25                      16430     341.661775           32905
# 26                        273     217.184268             273

# %%
forecast = sarimax_result.get_forecast(steps=len(test), exog=[test[exog_vars]])
forecast_mean = forecast.predicted_mean
# Out:
# c:\Users\tn_ad\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\tn_ad\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
predict = forecast_mean.astype(int)
predict
# Out:
# 20    39249
# 21    39049
# 22    44068
# 23    40288
# 24    33539
# 25     3730
# Name: predicted_mean, dtype: int32

# %%
true = test['Predict_Demand']
true
# Out:
# Delivery Month
# 21    35788
# 22    42145
# 23    42896
# 24    35586
# 25    32905
# 26      273
# Name: Predict_Demand, dtype: int32

# %%
mse = mean_squared_error(true, predict)
rmse = np.sqrt(mse)
print(f'Root Mean Squared Error (RMSE): {rmse}')
# Out:
# Root Mean Squared Error (RMSE): 3092.9740272645895

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
X_train = train[['Average_Price', 'Advance_Order']]
y_train = train['Predict_Demand']

# %%
X_test = test[['Average_Price', 'Advance_Order']]
Y_test = test['Predict_Demand']

# %%
rf_model = RandomForestRegressor(n_estimators=50)
rf_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=50)

# %%
pred = rf_model.predict(X_test)

# %%
np.sqrt(mean_squared_error(pred,Y_test))
# Out:
# 8258.609040009906

# %% [markdown]
# ## Predict the demand for month 27

# %%
last_advance_order_value = df_demand['Advance_Order'].iloc[-1]

last_average_price_value = df_demand['Average_Price'].iloc[-1]

# %%
last_advance_order_value
# Out:
# 273

# %%
last_average_price_value
# Out:
# 217.18426787125435

# %%
exog_month27 = pd.DataFrame({'Advance Order': [last_advance_order_value], 'Average_Price': [last_average_price_value]})

# %%
forecast_month27 = sarimax_result.get_forecast(steps=1, exog=exog_month27)
print(f'Predicted Demand for Month 27: {forecast_month27.predicted_mean.astype(int).values[0]}')
# Out:
# Predicted Demand for Month 27: 8279
# c:\Users\tn_ad\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# c:\Users\tn_ad\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %% [markdown]
# Use the average price and predicted demand to determine the probablities of each product type

# %%
def months_to_month_of_year(incremental_month):
    # Assuming January is the starting month (1-based index)
    starting_month = 1
    
    # Calculate the month of the year
    month_of_year = (starting_month + incremental_month - 1) % 12
    
    return month_of_year

# %%
incremental_month_value = 27
result_month = months_to_month_of_year(incremental_month_value)

print(f"{incremental_month_value} months is equivalent to month {result_month}")
# Out:
# 27 months is equivalent to month 3

# %%
X_27month = pd.DataFrame({'MOY_Requested Delivery Date': [result_month], 'Items': [forecast_month27.predicted_mean.astype(int).values[0]], 'Average_Price': [last_average_price_value]})

# %%
X_27month['const'] = 1    
X_27month = X_27month[['const'] + [col for col in X_27month.columns if col != 'const']]
X_27month
# Out:
#    const  MOY_Requested Delivery Date  Items  Average_Price
# 0      1                            3   8279     217.184268

# %%
X_27month_scaled = scaler.transform(X_27month)

# %%
Y_prob_27month = result.predict(X_27month_scaled)
Y_prob_27month
# Out:
# array([[0.34082952, 0.32041114, 0.33875934]])

# %% [markdown]
# Cacluate the predicted demand for each product type for month 27

# %%
prob_product1 = Y_prob_27month[0, 0]
prob_product2 = Y_prob_27month[0, 1]
prob_product3 = Y_prob_27month[0, 2]

# %%
Product1 = (forecast_month27.predicted_mean.values[0] * prob_product1).astype(int)
Product2 = (forecast_month27.predicted_mean.values[0] * prob_product2).astype(int)
Product3 = (forecast_month27.predicted_mean.values[0] * prob_product3).astype(int)

# %%
result_table = pd.DataFrame({
    'Product1': [Product1],
    'Product2': [Product2],
    'Product3': [Product3]
}, index=['Predicted_demand'])

print(result_table)
# Out:
#                   Product1  Product2  Product3
# Predicted_demand      2821      2652      2804
